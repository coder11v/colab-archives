# %% [markdown]
# <a href="https://colab.research.google.com/github/coder11v/colab-archives/blob/main/2022/shopping_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Veer's Games!
#
#
#  [Refresh Page](https://colab.research.google.com/drive/1IEJaseJ22g3YUZP7Sy4y-PWzp7-hBkH0?usp=sharing)
#
#
# ---
#
#
#
# ```
# Only one game at a time!
# ```
#
#
#
# ---
#
# Click the arrow next to your game, then the Play, and play!

# %% [markdown]
# # Mad Libs

# %%
#@title Play "MadLibs" here! (Veer's version)
Your_Name = "Tarun" #@param {type:"string"}

def passtheword():
  password = None
  attempts = []
  while password != "madlibs":
    password = input ("Enter the password: ")
    attempts.append(password)
    if password != "madlibs":
      print("Your password is incorrect. You have guessed:")
      for i in attempts:
        print (i)
  print("You said Mad Libs. Let's play it then!")
#
#
def madlibs():
  words = []
  def prompt(kind):
    ask = ("Please enter " + kind + ": ")
    word = input(ask)
    words.append(word)

  prompt("an adjective")

  prompt("a nationity")

  prompt("a name for a person")

  prompt("an plural noun")

  prompt("an adjective")

  prompt("an plural noun")

  print("Computers were invented by a", words[0], words[1], "engineer named", words[2],". To make a computer, you need to take a lot of", words[3], ", melt them down, and make", words[4], words[5], "." )
#
#
#
#
#
passtheword()
madlibs()
print("Thank you for playing, " + Your_Name + ".")
# Out:
# Enter the password: madlibs
# You said Mad Libs. Let's play it then!
# Please enter an adjective: lovely
# Please enter a nationity: English
# Please enter a name for a person: Toto
# Please enter an plural noun: heads
# Please enter an adjective: pouty
# Please enter an plural noun: hands
# Computers were invented by a lovely English engineer named Toto . To make a computer, you need to take a lot of heads , melt them down, and make pouty hands .
# Thank you for playing, Veer.

# %% [markdown]
# # Shopping list

# %%
#@title Shopping list
def whats_on_the_telly(item):
    lister.append(item)
    return lister
lister = []
ttywt = 0
listreapeat = 1
while 1 == 1:
  ttywt = ttywt + 1
  rgd = (whats_on_the_telly(input('Add to shopping list or say "view" to view list: ')))
  if rgd[ttywt - listreapeat] == ("view"):
    rgd.remove("view")
    print(rgd)
    listreapeat = listreapeat + 1
# Out:
# Add to shopping list or say "view" to view list: Toilet paper
# Add to shopping list or say "view" to view list: view
# ['Toilet paper']
# Add to shopping list or say "view" to view list: sliced mango
# Add to shopping list or say "view" to view list: mixed berries (WF)
# Add to shopping list or say "view" to view list: view
# ['Toilet paper', 'sliced mango', 'mixed berries (WF)']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-9a0b6260874d> in <module>
#       8 while 1 == 1:
#       9   ttywt = ttywt + 1
# ---> 10   rgd = (whats_on_the_telly(input('Add to shopping list or say "view" to view list: ')))
#      11   if rgd[ttywt - listreapeat] == ("view"):
#      12     rgd.remove("view")
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
# ...
