# %% [markdown]
# <a href="https://colab.research.google.com/github/coder11v/colab-archives/blob/main/2022/PINencrypt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
base = "tyt" #@param {type:"string"}
PIN = 890 #@param {type:"number"}
print("Type your message in base, and your code for protection in PIN")

  secret_message = None
  secret_message = (base)
  base = None
  keyword = PIN
  if base != None and PIN != None:
    print("Then delete your message and PIN for security purposes.")
    #
    password = None
    attempts = []
    while password != (keyword):
      password = input ("Enter the PIN to view: ")
      attempts.append(password)
      if password != (keyword):
        print("Your PIN is incorrect. You have guessed:")
        for i in attempts:
          print (i)
    print(secret_message)
# Out:
# Type your message in base, and your code for protection in PIN
